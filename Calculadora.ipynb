# %% [markdown]
# <a href="https://colab.research.google.com/github/StackMilo/Curso_PythonIA/blob/main/Calculadora.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
number1 = int(input("Inserta el numero 1: "))
number2 = int(input("Inserta el numero 2: "))

def sum(number1, number2):
  result = number1 + number2
  print(f"El resultado de {number1} + {number2} es: ", result)

def sub(number1, number2):
  result = number1 - number2
  print(f"El resultado de {number1} - {number2} es: ", result)

def mul(number1, number2):
  result = number1 * number2
  print(f"El resultado de {number1} * {number2} es: ", result)

def div(number1, number2):
  if number2 != 0:
    result = number1 / number2
    print(f"El resultado de {number1} / {number2} es: ", result)
  else:
    print("No se puede dividir por cero")

sum(number1, number2)
sub(number1, number2)
mul(number1, number2)
div(number1, number2)
# Out:
# Inserta el numero 1: 5
# Inserta el numero 2: 8
# El resultado de 5 + 8 es:  13
# El resultado de 5 - 8 es:  -3
# El resultado de 5 * 8 es:  40
# El resultado de 5 / 8 es:  0.625
